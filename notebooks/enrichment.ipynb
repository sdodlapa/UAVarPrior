# %%
import os
import re
import numpy as np
import pandas as pd
import gzip
import time
import matplotlib.pyplot as plt
# %matplotlib inline
print('Packages loaded')
# Out:
# Packages loaded

# %%
def regex_match(start_with, end_with, folder):
    m = re.search(start_with+end_with, folder)
    if m!=None:
        return True
    else:
        return False

_maf_re = re.compile(r'\bMAF=([^;]+)')

def extract_maf_regex(info_str):
    """
    Use a regular expression to grab the MAF= value.
    """
    m = _maf_re.search(info_str)
    if not m:
        return None
    try:
        return float(m.group(1))
    except ValueError:
        return None

def classify_maf(maf):
    if maf < 0.001:
        return 'rare'
    elif maf > 0.05:
        return 'common'
    else:
        return 'none'

# %% [markdown]
# # pred1 Vs pred150: rare Vs common

# %%
inPath = '/scratch/ml-csm/datasets/genomics/ref-genome/human/GRCh38/ensembl/variants/processed/'
df_maf = pd.read_parquet(inPath+'1000GENOMES-release114-maf.parquet.gz')

df_maf['category'] = df_maf['maf'].apply(classify_maf)
df_maf.dropna(inplace=True, ignore_index=True)
df_maf
# Out:
#           chrom       pos           id ref    alt       maf category
# 0             1     51479  rs116400033   T      A  0.104199   common
# 1             1     51954  rs185832753   G  A,C,T  0.000196     rare
# 2             1     54490  rs141149254   G    A,C  0.096939   common
# 3             1     54669  rs532505601   C      T  0.000196     rare
# 4             1     54716  rs569128616   C    A,T  0.213305   common
# ...         ...       ...          ...  ..    ...       ...      ...
# 69542010     22  50795771    rs6010092   T      C  0.032182     none
# 69542011     22  50795915  rs374867791   G      T  0.076727   common
# 69542012     22  50796090  rs537052521   C      G  0.000196     rare
# 69542013     22  50796204    rs6010093   G    A,C  0.002943     none
# 69542014     22  50799907  rs541448644   A    G,T  0.000196     rare
#
# [69542015 rows x 7 columns]

# %%
group=2
inPath1 = '/scratch/ml-csm/projects/fgenom/gve/output/kmeans/annotations/sign_var_pred1/2/'
inPath150 = '/scratch/ml-csm/projects/fgenom/gve/output/kmeans/annotations/sign_var_pred150/2/'
files = os.listdir(inPath1)

rare_vs_common_dict = {}
for file in files:
    if regex_match('^.', '*.bed$', file):
        try:
            print(file)
            df1 = pd.read_csv(inPath1 + file, sep='\t', header=None)
            df1.columns = ['chrom', 'start', 'end', 'var_id', 'gve']
            # print(file, df1.shape)
            ind1 = df_maf['id'].isin(df1['var_id'])
            df_maf_pred1 = df_maf[ind1]
            rare_count = (df_maf_pred1['category'] == 'rare').sum()
            common_count = (df_maf_pred1['category'] == 'common').sum()
            # print(f'rare: {rare_count}, common: {common_count}')
    
            df150 = pd.read_csv(inPath150 + file, sep='\t', header=None)
            df150.columns = ['chrom', 'start', 'end', 'gve', 'pval', 'var_id']
            # print(file, df150.shape)
            ind150 = df_maf['id'].isin(df150['var_id'])
            df_maf_pred150 = df_maf[ind150]
            rare_count150 = (df_maf_pred150['category'] == 'rare').sum()
            common_count150 = (df_maf_pred150['category'] == 'common').sum()
            # print(f'rare: {rare_count150}, common: {common_count150}')
            rare_vs_common_dict[file[:-4]] = [df1.shape[0], rare_count, common_count, df150.shape[0], rare_count150, common_count150]
        except:
            print(f'something is wrong with {file}')
df = pd.DataFrame.from_dict(rare_vs_common_dict, orient='index', columns = ['pred1', 'pred1_rare', 'pred1_common', 'pred150', 'pred150_rare', 'pred150_common'])
df.insert(loc=0, column='profile', value=df.index)
df.insert(loc=4, column='pred1_rare_Vs_common', value=df['pred1_rare']/df['pred1_common'])
df.insert(loc=8, column='pred150_rare_Vs_common', value=df['pred150_rare']/df['pred150_common'])
df.to_csv(f'GVE_peak/data/enrich_ana/gp{group}_rare_Vs_common.csv', index=False)
df
# Out:
# spnlc_H3K36me3_None.bed
# brn_H3K36me3_None_1.bed
# nrn_H3K36me3_None.bed
# lyroh_H3K36me3_None_1.bed
# nrlc_H3K79me2_None.bed
# nrlpc_H3K36me3_None.bed
# SKNSH_H3K36me3_al_6M_48hr.bed
# nrnlsc_H3K79me1_None.bed
# nrlc_H4K20me1_None.bed
# nrlpc_H4K20me1_None.bed
# nrlpc_H3K79me2_None.bed
# brnmec_H3K36me3_None.bed
# sbstntn_H3K36me3_None_1.bed
# nrsphr_H3K36me3_None_2.bed
# strcyt_H3K36me3_None.bed
# cdtn_H3K36me3_None_2.bed
# SKNSH_H4K20me1_None.bed
# blrn_H4K20me1_do_0.5gmL_4d.bed
# blrn_H3K36me3_do_0.5gmL_4d.bed
# SKNSH_H3K36me3_None_1.bed
# strcyt_H3K79me2_None.bed
# SKNSH_H3K79me2_None.bed
# blrn_H3K79me2_do_0.5gmL_4d.bed
# nrlc_H3K36me3_None.bed
# mddlfa4_H3K36me3_None_1.bed
# cngltg_H3K36me3_None_2.bed
# nrnlsc_H3K36me3_None_1.bed
# SK-N-MC_H3K36me3_None.bed
# grmnlm_H3K36me3_None_2.bed
# strcyt_H4K20me1_None.bed
# tmprll_H3K36me3_None_2.bed
# BE2C_H3K36me3_None.bed
# nglrg_H3K36me3_None_1.bed
# tbln_H3K36me3_None_3.bed
#                               pred1  pred1_rare  pred1_common  pred150  \
# spnlc_H3K36me3_None          553128        5662          7436   266916
# brn_H3K36me3_None_1         1017283       20222         10040   354569
# nrn_H3K36me3_None            167375        1628          1997   520513
# lyroh_H3K36me3_None_1         96559        1445           331   104889
# nrlc_H3K79me2_None          2598860       56307         28012    68632
# nrlpc_H3K36me3_None          469180        5226          5965    70449
# SKNSH_H3K36me3_al_6M_48hr    800188        8682         10191    43799
# nrnlsc_H3K79me1_None         160698        1590          1922     7150
# nrlc_H4K20me1_None           156823        1608          1902       58
# nrlpc_H4K20me1_None          496669       11364          3090    59768
# nrlpc_H3K79me2_None          464308        8671          2835   282114
# brnmec_H3K36me3_None         950554       20201          7050   232639
# sbstntn_H3K36me3_None_1      164755        2592          1294   102422
# nrsphr_H3K36me3_None_2       372204        4268          4134   589820
# strcyt_H3K36me3_None          13395          65            72   196398
# cdtn_H3K36me3_None_2         553672        6597          7396    99246
# SKNSH_H4K20me1_None          418851       10178          1900    71377
# blrn_H4K20me1_do_0.5gmL_4d  1864342       39361         18108   240289
# blrn_H3K36me3_do_0.5gmL_4d       64           0             0   507570
# SKNSH_H3K36me3_None_1        600255       15077          3101   307665
# strcyt_H3K79me2_None         479861       11413          2312   330824
# SKNSH_H3K79me2_None          550599       15707          2391   378066
# blrn_H3K79me2_do_0.5gmL_4d   821201        8932         11835   339908
# nrlc_H3K36me3_None           643861       14729          3778     3990
# mddlfa4_H3K36me3_None_1     1497159       35456         12717   177460
# cngltg_H3K36me3_None_2       477973       12412          2177   155960
# nrnlsc_H3K36me3_None_1      1402089       27946         13810  1050729
# SK-N-MC_H3K36me3_None        928878       18482          7198   271078
# grmnlm_H3K36me3_None_2       390248        9679          1668   230020
# strcyt_H4K20me1_None         551633       11593          3910   154654
# tmprll_H3K36me3_None_2      1016717       22440          8486    97564
# BE2C_H3K36me3_None          1931748       43988         18038   320465
# nglrg_H3K36me3_None_1        443751       10582          2056    33209
# tbln_H3K36me3_None_3           3618          20             6   664927
#
#                             pred150_rare  pred150_common
# spnlc_H3K36me3_None                10012            6272
# brn_H3K36me3_None_1                13447            8178
# nrn_H3K36me3_None                  19770           11739
# lyroh_H3K36me3_None_1               4006            2477
# nrlc_H3K79me2_None                  2572            1775
# nrlpc_H3K36me3_None                 2697            1635
# SKNSH_H3K36me3_al_6M_48hr           1719            1060
# nrnlsc_H3K79me1_None                 296             172
# nrlc_H4K20me1_None                     3               0
# nrlpc_H4K20me1_None                 2225            1489
# nrlpc_H3K79me2_None                10705            6930
# brnmec_H3K36me3_None                8946            5412
# sbstntn_H3K36me3_None_1             3952            2394
# nrsphr_H3K36me3_None_2             22052           13146
# strcyt_H3K36me3_None                7584            4640
# cdtn_H3K36me3_None_2                3826            2347
# SKNSH_H4K20me1_None                 2721            1842
# blrn_H4K20me1_do_0.5gmL_4d          8980            5766
# blrn_H3K36me3_do_0.5gmL_4d         19104           11377
# SKNSH_H3K36me3_None_1              11687            6940
# strcyt_H3K79me2_None               12668            8077
# SKNSH_H3K79me2_None                14227            9143
# blrn_H3K79me2_do_0.5gmL_4d         12747            8240
# nrlc_H3K36me3_None                   166              89
# mddlfa4_H3K36me3_None_1             6844            4178
# cngltg_H3K36me3_None_2              5998            3671
# nrnlsc_H3K36me3_None_1             39398           23522
# SK-N-MC_H3K36me3_None              10341            6210
# grmnlm_H3K36me3_None_2              8718            5365
# strcyt_H4K20me1_None                5957            3802
# tmprll_H3K36me3_None_2              3799            2256
# BE2C_H3K36me3_None                 12247            7516
# nglrg_H3K36me3_None_1               1283             792
# tbln_H3K36me3_None_3               24996           14962

# %%
group=3
inPath1 = f'/scratch/ml-csm/projects/fgenom/gve/output/kmeans/annotations/sign_var_pred1/{group}/'
inPath150 = f'/scratch/ml-csm/projects/fgenom/gve/output/kmeans/annotations/sign_var_pred150/{group}/'
files = os.listdir(inPath1)

rare_vs_common_dict = {}
for file in files:
    if regex_match('^.', '*.bed$', file):
        try:
            print(file)
            df1 = pd.read_csv(inPath1 + file, sep='\t', header=None)
            df1.columns = ['chrom', 'start', 'end', 'var_id', 'gve']
            # print(file, df1.shape)
            ind1 = df_maf['id'].isin(df1['var_id'])
            df_maf_pred1 = df_maf[ind1]
            rare_count = (df_maf_pred1['category'] == 'rare').sum()
            common_count = (df_maf_pred1['category'] == 'common').sum()
            # print(f'rare: {rare_count}, common: {common_count}')
    
            df150 = pd.read_csv(inPath150 + file, sep='\t', header=None)
            df150.columns = ['chrom', 'start', 'end', 'gve', 'pval', 'var_id']
            # print(file, df150.shape)
            ind150 = df_maf['id'].isin(df150['var_id'])
            df_maf_pred150 = df_maf[ind150]
            rare_count150 = (df_maf_pred150['category'] == 'rare').sum()
            common_count150 = (df_maf_pred150['category'] == 'common').sum()
            # print(f'rare: {rare_count150}, common: {common_count150}')
            rare_vs_common_dict[file[:-4]] = [df1.shape[0], rare_count, common_count, df150.shape[0], rare_count150, common_count150]
        except:
            print(f'something is wrong with {file}')
df = pd.DataFrame.from_dict(rare_vs_common_dict, orient='index', columns = ['pred1', 'pred1_rare', 'pred1_common', 'pred150', 'pred150_rare', 'pred150_common'])
df.insert(loc=0, column='profile', value=df.index)
df.insert(loc=4, column='pred1_rare_Vs_common', value=df['pred1_rare']/df['pred1_common'])
df.insert(loc=8, column='pred150_rare_Vs_common', value=df['pred150_rare']/df['pred150_common'])
df.to_csv(f'GVE_peak/data/enrich_ana/gp{group}_rare_Vs_common.csv', index=False)
df
# Out:
# nrnlsc_H3K27me3_None_1.bed
# tbln_H3K9me3_None_2.bed
# cdtn_H3K27me3_None_2.bed
# SKNSH_H3K9me3_None_1.bed
# tmprll_H3K9me3_None_1.bed
# lyroh_H3K27me3_None_2.bed
# lyroh_H3K9me3_None_3.bed
# nrnlsc_H3K9me3_None_1.bed
# nrsphr_H3K9me3_None_4.bed
# tbln_H3K27me3_None_2.bed
# nrn_H3K27me3_None.bed
# brnmec_H3K27me3_None.bed
# cdtn_H3K9me3_None_1.bed
# spnlc_H3K9me3_None.bed
# strcyt_EZH2_None.bed
# mddlfa4_H3K9me3_None_2.bed
# strcyt_H3K9me3_None.bed
# nrn_H3K9me3_None.bed
# tmprll_H3K27me3_None_2.bed
# blrn_H3K27me3_do_0.5gmL_4d.bed
# SKNSH_H3K27me3_None.bed
# nglrg_H3K27me3_None.bed
# SKNSH_H3K27me3_al_6M_48hr.bed
# nrlc_H3K9me3_None.bed
# nrlc_H3K27me3_None.bed
# brn_H3K9me3_None_1.bed
# cngltg_H3K9me3_None_1.bed
# grmnlm_H3K9me3_None_2.bed
# SK-N-MC_EZH2_None.bed
# blrn_H3K9me2_do_0.5gmL_4d.bed
# sbstntn_H3K9me3_None_1.bed
# cngltg_H3K27me3_None.bed
# nrlpc_H3K27me3_None.bed
# grmnlm_H3K27me3_None_2.bed
# BE2C_H3K27me3_None.bed
# SKNSH_EZH2_None.bed
# something is wrong with SKNSH_EZH2_None.bed
# nrlpc_H3K9me3_None.bed
# brn_H3K27me3_None_1.bed
# nrsphr_H3K27me3_None_2.bed
# SK-N-MC_H3K9me3_None.bed
# blrn_H3K9me3_do_0.5gmL_4d.bed
# nglrg_H3K9me3_None_2.bed
# SKNSH_H3K9me2_None.bed
# md-nrgnssrgc_H3K27me3_None.bed
# BE2C_H3K9me3_None.bed
# nrlc_EZH2_None.bed
# md-nrgnssrgc_H3K9me3_None.bed
# something is wrong with md-nrgnssrgc_H3K9me3_None.bed
# nrlpc_EZH2_None_1.bed
# mddlfa4_H3K27me3_None.bed
# spnlc_H3K27me3_None.bed
# sbstntn_H3K27me3_None_2.bed
# /home/sdodl001/envs/fugep/lib/python3.10/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /home/sdodl001/envs/fugep/lib/python3.10/site-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /home/sdodl001/envs/fugep/lib/python3.10/site-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                profile   pred1  pred1_rare  \
# nrnlsc_H3K27me3_None_1          nrnlsc_H3K27me3_None_1    9792         106
# tbln_H3K9me3_None_2                tbln_H3K9me3_None_2   93044        1004
# cdtn_H3K27me3_None_2              cdtn_H3K27me3_None_2   69272        3269
# SKNSH_H3K9me3_None_1              SKNSH_H3K9me3_None_1  161309        1594
# tmprll_H3K9me3_None_1            tmprll_H3K9me3_None_1   45610         581
# lyroh_H3K27me3_None_2            lyroh_H3K27me3_None_2   30724        1261
# lyroh_H3K9me3_None_3              lyroh_H3K9me3_None_3  178222        1985
# nrnlsc_H3K9me3_None_1            nrnlsc_H3K9me3_None_1  185756        2183
# nrsphr_H3K9me3_None_4            nrsphr_H3K9me3_None_4   11167         646
# tbln_H3K27me3_None_2              tbln_H3K27me3_None_2   27624         223
# nrn_H3K27me3_None                    nrn_H3K27me3_None      16           0
# brnmec_H3K27me3_None              brnmec_H3K27me3_None  115698        1238
# cdtn_H3K9me3_None_1                cdtn_H3K9me3_None_1  109849        4752
# spnlc_H3K9me3_None                  spnlc_H3K9me3_None   30026         338
# strcyt_EZH2_None                      strcyt_EZH2_None   51757         637
# mddlfa4_H3K9me3_None_2          mddlfa4_H3K9me3_None_2  179599        1915
# strcyt_H3K9me3_None                strcyt_H3K9me3_None  269814        2581
# nrn_H3K9me3_None                      nrn_H3K9me3_None   44406         398
# tmprll_H3K27me3_None_2          tmprll_H3K27me3_None_2   94031        4428
# blrn_H3K27me3_do_0.5gmL_4d  blrn_H3K27me3_do_0.5gmL_4d  108519        1119
# SKNSH_H3K27me3_None                SKNSH_H3K27me3_None   16976         168
# nglrg_H3K27me3_None                nglrg_H3K27me3_None   29712        1565
# SKNSH_H3K27me3_al_6M_48hr    SKNSH_H3K27me3_al_6M_48hr   41214        1905
# nrlc_H3K9me3_None                    nrlc_H3K9me3_None  152641        1862
# nrlc_H3K27me3_None                  nrlc_H3K27me3_None   24420         999
# brn_H3K9me3_None_1                  brn_H3K9me3_None_1   53040        2472
# cngltg_H3K9me3_None_1            cngltg_H3K9me3_None_1   31782         322
# grmnlm_H3K9me3_None_2            grmnlm_H3K9me3_None_2  113800        1249
# SK-N-MC_EZH2_None                    SK-N-MC_EZH2_None       2           0
# blrn_H3K9me2_do_0.5gmL_4d    blrn_H3K9me2_do_0.5gmL_4d  171611        6722
# sbstntn_H3K9me3_None_1          sbstntn_H3K9me3_None_1   66102         821
# cngltg_H3K27me3_None              cngltg_H3K27me3_None  246464        7185
# nrlpc_H3K27me3_None                nrlpc_H3K27me3_None      40           0
# grmnlm_H3K27me3_None_2          grmnlm_H3K27me3_None_2  144794        1572
# BE2C_H3K27me3_None                  BE2C_H3K27me3_None    1416          10
# nrlpc_H3K9me3_None                  nrlpc_H3K9me3_None   12779         342
# brn_H3K27me3_None_1                brn_H3K27me3_None_1  679513       22934
# nrsphr_H3K27me3_None_2          nrsphr_H3K27me3_None_2  272184        7973
# SK-N-MC_H3K9me3_None              SK-N-MC_H3K9me3_None      23           1
# blrn_H3K9me3_do_0.5gmL_4d    blrn_H3K9me3_do_0.5gmL_4d   34522        1730
# nglrg_H3K9me3_None_2              nglrg_H3K9me3_None_2   78945         647
# SKNSH_H3K9me2_None                  SKNSH_H3K9me2_None  224038        1953
# md-nrgnssrgc_H3K27me3_None  md-nrgnssrgc_H3K27me3_None  106228        3516
# BE2C_H3K9me3_None                    BE2C_H3K9me3_None  104977         980
# nrlc_EZH2_None                          nrlc_EZH2_None      43           0
# nrlpc_EZH2_None_1                    nrlpc_EZH2_None_1     260           1
# mddlfa4_H3K27me3_None            mddlfa4_H3K27me3_None  906527       29148
# spnlc_H3K27me3_None                spnlc_H3K27me3_None   54423         436
# sbstntn_H3K27me3_None_2        sbstntn_H3K27me3_None_2      11           0
#
#                             pred1_common  pred1_rare_Vs_common  pred150  \
# nrnlsc_H3K27me3_None_1                88              1.204545    45991
# tbln_H3K9me3_None_2                  923              1.087757   525902
# cdtn_H3K27me3_None_2                 739              4.423545     2806
# SKNSH_H3K9me3_None_1                1499              1.063376    66651
# tmprll_H3K9me3_None_1                409              1.420538    69775
# lyroh_H3K27me3_None_2                245              5.146939     5009
# lyroh_H3K9me3_None_3                1532              1.295692    40517
# nrnlsc_H3K9me3_None_1               1735              1.258213    98753
# nrsphr_H3K9me3_None_4                103              6.271845   739742
# tbln_H3K27me3_None_2                 238              0.936975    53370
# nrn_H3K27me3_None                      0                   NaN    36800
# brnmec_H3K27me3_None                1045              1.184689    28479
# cdtn_H3K9me3_None_1                 1255              3.786454    79914
# spnlc_H3K9me3_None                   266              1.270677    17033
# strcyt_EZH2_None                     461              1.381779    11746
# mddlfa4_H3K9me3_None_2              1587              1.206679    21992
# strcyt_H3K9me3_None                 2649              0.974330    16577
# nrn_H3K9me3_None                     416              0.956731    17854
# tmprll_H3K27me3_None_2              1077              4.111421    18011
# blrn_H3K27me3_do_0.5gmL_4d           969              1.154799    87741
# SKNSH_H3K27me3_None                  151              1.112583    15963
# nglrg_H3K27me3_None                  294              5.323129    13593
# SKNSH_H3K27me3_al_6M_48hr            389              4.897172     9440
# nrlc_H3K9me3_None                   1341              1.388516       22
# nrlc_H3K27me3_None                   211              4.734597    69762
# brn_H3K9me3_None_1                   531              4.655367   175626
# cngltg_H3K9me3_None_1                299              1.076923    25415
# grmnlm_H3K9me3_None_2               1096              1.139599   208777
# SK-N-MC_EZH2_None                      0                   NaN        2
# blrn_H3K9me2_do_0.5gmL_4d           2089              3.217808        1
# sbstntn_H3K9me3_None_1               580              1.415517    26397
# cngltg_H3K27me3_None                3086              2.328257    23204
# nrlpc_H3K27me3_None                    0                   NaN    72721
# grmnlm_H3K27me3_None_2              1226              1.282219    84118
# BE2C_H3K27me3_None                    11              0.909091    22109
# nrlpc_H3K9me3_None                   125              2.736000     8278
# brn_H3K27me3_None_1                 8644              2.653170    58597
# nrsphr_H3K27me3_None_2              3201              2.490784    34378
# SK-N-MC_H3K9me3_None                   0                   inf      170
# blrn_H3K9me3_do_0.5gmL_4d            360              4.805556  1096615
# nglrg_H3K9me3_None_2                 692              0.934971    25582
# SKNSH_H3K9me2_None                  2118              0.922096       52
# md-nrgnssrgc_H3K27me3_None          1451              2.423156    44603
# BE2C_H3K9me3_None                    982              0.997963        3
# nrlc_EZH2_None                         0                   NaN      181
# nrlpc_EZH2_None_1                      1              1.000000    43021
# mddlfa4_H3K27me3_None              11175              2.608322     8857
# spnlc_H3K27me3_None                  515              0.846602    55209
# sbstntn_H3K27me3_None_2                0                   NaN    11226
#
#                             pred150_rare  pred150_common  \
# nrnlsc_H3K27me3_None_1               321             404
# tbln_H3K9me3_None_2                17001            6665
# cdtn_H3K27me3_None_2                  16              19
# SKNSH_H3K9me3_None_1                2355             807
# tmprll_H3K9me3_None_1               3350             825
# lyroh_H3K27me3_None_2                 32              33
# lyroh_H3K9me3_None_3                2139             448
# nrnlsc_H3K9me3_None_1               4555            1132
# nrsphr_H3K9me3_None_4              21348            9078
# tbln_H3K27me3_None_2                 350             461
# nrn_H3K27me3_None                    271             326
# brnmec_H3K27me3_None                 181             239
# cdtn_H3K9me3_None_1                 3953             927
# spnlc_H3K9me3_None                   978             170
# strcyt_EZH2_None                      44              91
# mddlfa4_H3K9me3_None_2              1226             220
# strcyt_H3K9me3_None                  894             158
# nrn_H3K9me3_None                     866             154
# tmprll_H3K27me3_None_2               142             160
# blrn_H3K27me3_do_0.5gmL_4d           599             772
# SKNSH_H3K27me3_None                   79             143
# nglrg_H3K27me3_None                   98             118
# SKNSH_H3K27me3_al_6M_48hr             54              76
# nrlc_H3K9me3_None                      0               0
# nrlc_H3K27me3_None                   516             646
# brn_H3K9me3_None_1                  5576            2122
# cngltg_H3K9me3_None_1               1372             257
# grmnlm_H3K9me3_None_2               6819            2283
# SK-N-MC_EZH2_None                      0               0
# blrn_H3K9me2_do_0.5gmL_4d              0               0
# sbstntn_H3K9me3_None_1              1514             269
# cngltg_H3K27me3_None                 174             198
# nrlpc_H3K27me3_None                  467             638
# grmnlm_H3K27me3_None_2               517             693
# BE2C_H3K27me3_None                   124             186
# nrlpc_H3K9me3_None                   247              89
# brn_H3K27me3_None_1                  376             523
# nrsphr_H3K27me3_None_2               189             301
# SK-N-MC_H3K9me3_None                   0               0
# blrn_H3K9me3_do_0.5gmL_4d          23126           15331
# nglrg_H3K9me3_None_2                1388             277
# SKNSH_H3K9me2_None                     0               1
# md-nrgnssrgc_H3K27me3_None           324             401
# BE2C_H3K9me3_None                      0               0
# nrlc_EZH2_None                         0               1
# nrlpc_EZH2_None_1                    242             387
# mddlfa4_H3K27me3_None                 61              82
# spnlc_H3K27me3_None                  426             469
# sbstntn_H3K27me3_None_2               72              94
#
#                             pred150_rare_Vs_common
# nrnlsc_H3K27me3_None_1                    0.794554
# tbln_H3K9me3_None_2                       2.550788
# cdtn_H3K27me3_None_2                      0.842105
# SKNSH_H3K9me3_None_1                      2.918216
# tmprll_H3K9me3_None_1                     4.060606
# lyroh_H3K27me3_None_2                     0.969697
# lyroh_H3K9me3_None_3                      4.774554
# nrnlsc_H3K9me3_None_1                     4.023852
# nrsphr_H3K9me3_None_4                     2.351619
# tbln_H3K27me3_None_2                      0.759219
# nrn_H3K27me3_None                         0.831288
# brnmec_H3K27me3_None                      0.757322
# cdtn_H3K9me3_None_1                       4.264293
# spnlc_H3K9me3_None                        5.752941
# strcyt_EZH2_None                          0.483516
# mddlfa4_H3K9me3_None_2                    5.572727
# strcyt_H3K9me3_None                       5.658228
# nrn_H3K9me3_None                          5.623377
# tmprll_H3K27me3_None_2                    0.887500
# blrn_H3K27me3_do_0.5gmL_4d                0.775907
# SKNSH_H3K27me3_None                       0.552448
# nglrg_H3K27me3_None                       0.830508
# SKNSH_H3K27me3_al_6M_48hr                 0.710526
# nrlc_H3K9me3_None                              NaN
# nrlc_H3K27me3_None                        0.798762
# brn_H3K9me3_None_1                        2.627710
# cngltg_H3K9me3_None_1                     5.338521
# grmnlm_H3K9me3_None_2                     2.986859
# SK-N-MC_EZH2_None                              NaN
# blrn_H3K9me2_do_0.5gmL_4d                      NaN
# sbstntn_H3K9me3_None_1                    5.628253
# cngltg_H3K27me3_None                      0.878788
# nrlpc_H3K27me3_None                       0.731975
# grmnlm_H3K27me3_None_2                    0.746032
# BE2C_H3K27me3_None                        0.666667
# nrlpc_H3K9me3_None                        2.775281
# brn_H3K27me3_None_1                       0.718929
# nrsphr_H3K27me3_None_2                    0.627907
# SK-N-MC_H3K9me3_None                           NaN
# blrn_H3K9me3_do_0.5gmL_4d                 1.508447
# nglrg_H3K9me3_None_2                      5.010830
# SKNSH_H3K9me2_None                        0.000000
# md-nrgnssrgc_H3K27me3_None                0.807980
# BE2C_H3K9me3_None                              NaN
# nrlc_EZH2_None                            0.000000
# nrlpc_EZH2_None_1                         0.625323
# mddlfa4_H3K27me3_None                     0.743902
# spnlc_H3K27me3_None                       0.908316
# sbstntn_H3K27me3_None_2                   0.765957

# %%
group = 2
df_gp2 = pd.read_csv(f'GVE_peak/data/enrich_ana/gp{group}_rare_Vs_common.csv')
group = 3
df_gp3 = pd.read_csv(f'GVE_peak/data/enrich_ana/gp{group}_rare_Vs_common.csv')

# %%
df = df_gp2.loc[:, ['profile', 'pred1_rare_Vs_common', 'pred150_rare_Vs_common']]

import numpy as np
import matplotlib.pyplot as plt

# Suppose your DataFrame is named `df`
# and has columns: "profile", "pred1_rare_Vs_common", "pred150_rare_Vs_common"

profiles = df['profile'].tolist()
vals1    = df['pred1_rare_Vs_common'].fillna(0).tolist()   # handle any NaNs
vals2    = df['pred150_rare_Vs_common'].fillna(0).tolist()

x = np.arange(len(profiles))
width = 0.35  # width of each bar

fig, ax = plt.subplots(figsize=(14, 6))

# plot the two sets of bars
ax.bar(x - width/2, vals1, width, label='pred1_rare_Vs_common')
ax.bar(x + width/2, vals2, width, label='pred150_rare_Vs_common')

# set ticks and labels
ax.set_xticks(x)
ax.set_xticklabels(profiles, rotation=90, ha='center')
ax.set_xlabel('Profile')
ax.set_ylabel('Value')
ax.set_title('Comparison of pred1 vs. pred150 per Profile')
ax.legend()

plt.tight_layout()
plt.show()

# %%
df = df_gp3.loc[:, ['profile', 'pred1_rare_Vs_common', 'pred150_rare_Vs_common']]

import numpy as np
import matplotlib.pyplot as plt

# Suppose your DataFrame is named `df`
# and has columns: "profile", "pred1_rare_Vs_common", "pred150_rare_Vs_common"

profiles = df['profile'].tolist()
vals1    = df['pred1_rare_Vs_common'].fillna(0).tolist()   # handle any NaNs
vals2    = df['pred150_rare_Vs_common'].fillna(0).tolist()

x = np.arange(len(profiles))
width = 0.35  # width of each bar

fig, ax = plt.subplots(figsize=(14, 6))

# plot the two sets of bars
ax.bar(x - width/2, vals1, width, label='pred1_rare_Vs_common')
ax.bar(x + width/2, vals2, width, label='pred150_rare_Vs_common')

# set ticks and labels
ax.set_xticks(x)
ax.set_xticklabels(profiles, rotation=90, ha='center')
ax.set_xlabel('Profile')
ax.set_ylabel('Value')
ax.set_title('Comparison of pred1 vs. pred150 per Profile')
ax.legend()

plt.tight_layout()
plt.show()
